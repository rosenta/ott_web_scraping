# %%
import pandas as pd

# %%
df = pd.read_csv("hm_prime_video_tv_shows.csv")

# %%
df.drop_duplicates(subset=['title_id'])
# Out:
#                                               title_id  \
# 0    amzn1.dv.gti.5c2c1110-ccb6-4922-9690-1193f46fa535
# 1    amzn1.dv.gti.fea52afa-4eb3-473b-8deb-e143cf7de4c8
# 2    amzn1.dv.gti.86467b47-3514-48af-9b5f-3da89708982a
# 3    amzn1.dv.gti.27dbd874-f83e-459d-b532-c8d99e535c04
# 4    amzn1.dv.gti.ff3e6df2-2fa6-4a7c-bab3-43972be660cb
# ..                                                 ...
# 712  amzn1.dv.gti.56b8ec53-7b14-4d6f-9445-25a2bff15771
# 713  amzn1.dv.gti.1cb016e6-fd15-352f-6be0-e1a81372c0e8
# 714  amzn1.dv.gti.dc022220-6b0c-4291-ab05-0e4ef65d6cdf
# 715  amzn1.dv.gti.f4b4390b-11cc-b5c4-a7f5-0ad37edf6036
# 716  amzn1.dv.gti.9d577c6a-4518-478e-a6f7-7f9a85025602
#
#                                            name  \
# 0                            Reacher - Season 2
# 1                                   Wedding.con
# 2                             Flames - Season 4
# 3                            Vyooham - Season 1
# 4                   Marry My Husband - Season 1
# ...
